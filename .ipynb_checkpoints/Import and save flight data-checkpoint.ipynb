# %%
import tensorflow as tf
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
DATADIR = "C:/Users/nermi/Desktop/dataset/Landing Stripe"

CATEGORIES = ["forward", "roll_left", "roll_right", "yaw_left", "yaw_right"]

IMG_SIZE = 70

training_data = []

def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category) # create path to forward, left and right
        class_num = CATEGORIES.index(category) # get the classification  (0, 1 or a 2). 0=forward 1=left 2=right

        for img in tqdm(os.listdir(path)): # iterate over each image 
            try:
                img_array = cv2.imread(os.path.join(path,img))  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass

create_training_data()

print(len(training_data))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1645/1645 [04:33<00:00,  7.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2211/2211 [05:40<00:00, 13.50it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2194/2194 [03:15<00:00, 11.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1780/1780 [02:55<00:00, 10.12it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1762/1762 [03:25<00:00,  7.29it/s]
# 9590

# %%
plt.imshow(training_data[5000][0])
plt.show()
print(training_data[10][0].shape)
# Out:
# (80, 80, 3)

# %%
#Shuffle the data
import random

random.shuffle(training_data)

# %%
import numpy as np

X = []
y = []

for features, label in training_data:
    X.append(features)
    y.append(label)

#print(X[0].reshape(-1, IMG_SIZE, IMG_SIZE, 1))

#X has to be a numpy array while y can stay a list
#-1: take all features, 1: image is a grayscale (one color channel)
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)

# %%
plt.imshow(X[0])
plt.show()
print(X[0].shape)
# Out:
# (80, 80, 3)

# %%
#Save the training data to a pickle file
import pickle

pickle_out = open("Dataset/X_landing_stripe_RGB.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("Dataset/y_landing_stripe_RGB.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()
